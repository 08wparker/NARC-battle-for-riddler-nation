# %% [markdown]
# # Kmeans clustering & PCA of troop deployment strategies for fivethirtyeight's Battle for Riddler Nation

# %%
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans

import matplotlib.pyplot as plt

# %%
data = pd.read_csv("clean_comp_3_data.csv")

data
# Out:
#       Castle 1  Castle 2  Castle 3  Castle 4  Castle 5  Castle 6  Castle 7  \
# 0            2         2         2         2         6        18         2
# 1            1         2         1        11        19        27        37
# 2            2         2         4         5         6        22         6
# 3            2         2         4         6         6        10        11
# 4            1         2         2         3        16        22         1
# 5            2         2        11        12        12        16        16
# 6            1         2         1         9         3         1        24
# 7            1         2         5         8         9        11        12
# 8            4         2        14        13        13         2        15
# 9            2         2         5        20         4        20         4
# 10           1         2        12        14         7        16        18
# 11           1         2         1         3         5        20        21
# 12           3         2        12        14         5        19        23
# 13           4         2         0         0         0         0         0
# 14           1         2         6        10        14        15        23
# 15           1         2         1         2         1        15        21
# 16           1         2         1        21         1         1        21
# 17           1         2         0         0         1        14        33
# 18           1         2         1         1         1        19        19
# 19           3         2         7         9        11         2        16
# 20           1         2         1         1        23        23        24
# 21           3         2         3         3         3        10        15
# 22           1         2         2         8        10        15        17
# 23           4         2         7         4         4         4        32
# 24           2         2         3        14         2        16         2
# 25           2         2         4         5         7         9        26
# 26           4         2         4         4        16         4        16
# 27           6         2         7         0         0         0        22
# 28           3         2         6        10        13        18        29
# 29           2         2         9         9        12         2        29
# ...        ...       ...       ...       ...       ...       ...       ...
# 1288         0         2         5        10         5         4        15
# 1289         1         2         1         1         1         6        13
# 1290         4         2         4        12         2        18        19
# 1291         4         2         8         6         7        15        18
# 1292         4         2         7         1         1        15        18
# 1293         1         2         1         7        10        10        20
# 1294         3         2         7        11        14        16        19
# 1295         5         2         5         7        22        23        22
# 1296         0         2         3         8         5        19        19
# 1297         3         2         3         3         3         3         3
# 1298         1         2         1         1         1         1        23
# 1299         3         2         1         9        18        13        15
# 1300         0         2         2        16        21         2         3
# 1301         2         2         3         5         5         8        10
# 1302         1         2         1         5         5        15        16
# 1303         1         2         4        10        21        12        26
# 1304         2         2         6         9         0         3         3
# 1305         3         2         7         4         4        24         5
# 1306         0         2         1        14         7         7        17
# 1307         1         2         1         6         6        12        16
# 1308         2         2         1         1         1        13        22
# 1309         2         2        10        10        10         5        20
# 1310         4         2         9        11        17        19         0
# 1311         1         2         8        16        16         5        14
# 1312         1         2         1         8         1        13        15
# 1313         0         2         0        18        18         2         2
# 1314         1         2         4         8        10        12        13
# 1315         0         2         2        16        21         2         3
# 1316         0         2         3         3        16         6        16
# 1317         1         2         0         0         0         0        10
#
#       Castle 8  Castle 9  Castle 10
# 0           28        36          2
# 1            1         1          1
# 2           22        22          8
# 3           14        17         28
# 4            1        33         20
# 5           17         6          6
# 6           28        31          1
# 7           15        16         19
# 8           15        10         10
# 9           20         4         20
# 10          20         3          5
# 11          33         7          7
# 12          12         6          4
# 13          31        31         31
# 14          24         3          3
# 15          26        31          1
# 16          21        31          1
# 17          33        14          2
# 18          19        19         19
# 19          19        15         14
# 20          24         1          1
# 21          20        30         10
# 22          19        23          3
# 23          34         4          4
# 24           4        32         23
# 25          33         6          5
# 26          29        16          4
# 27          26         0         36
# 28           7         6          5
# 29          28         2          3
# ...        ...       ...        ...
# 1288        10        25         25
# 1289        19        25         32
# 1290        28         5          5
# 1291         6        18         14
# 1292        21        18         14
# 1293         0        20         30
# 1294        22         3          3
# 1295         2         2         10
# 1296        20        20          3
# 1297        26        26         27
# 1298        69         1          1
# 1299        20        11          7
# 1300         1        32         22
# 1301        15        20         30
# 1302         1        24         31
# 1303        16         4          4
# 1304        21        24         29
# 1305        34         8          8
# 1306        22        23          9
# 1307        21        31          5
# 1308        34        24          1
# 1309        30         5          5
# 1310         0         0         38
# 1311        15        18          5
# 1312        17        19         21
# 1313         2        33         24
# 1314        15        17         18
# 1315         1        32         22
# 1316        21         4         30
# 1317        26        28         32
#
# [1318 rows x 10 columns]

# %% [markdown]
# # PCA on the strategies

# %% [markdown]
# **a) Extract Principal Components**
#
# I will use the singular value decomposition approach to PCA, i.e. for the training set $X$ I will find orthogonal matrices $U$ annd $V$ and diagonal matrix $\Sigma$ such that
#
# $X = U \Sigma V^t$

# %%
U, S, Vh = np.linalg.svd(data.values)

# %% [markdown]
# get first two PCA components

# %%
pca_1 = Vh.T[:,1]

pca_2 = Vh.T[:,2]

# %%
pca_1
# Out:
# array([-0.00791869, -0.00763391, -0.04222202, -0.10736375, -0.15764914,
#        -0.28993951, -0.47265861, -0.32644463,  0.4349875 ,  0.5987193 ])

# %%
pca_2
# Out:
# array([ 0.01098194,  0.00762154,  0.08052942,  0.08332442,  0.12769281,
#         0.21840716,  0.07967226, -0.17011742, -0.69518318,  0.63546751])

# %% [markdown]
# # K-means cluster the strategies

# %%
def cluster_and_plot(k, data, pca_1, pca_2):
    kmeans = KMeans(n_clusters=k).fit(data)
    p_clusters = kmeans.predict(data)
    
    
    pca_1_proj = data.values.dot(pca_1)

    pca_2_proj = data.values.dot(pca_2)
    
    plot = plt.scatter(x = pca_1_proj, y = pca_2_proj, c = p_clusters)
    
    cluster_counts = np.unique(p_clusters, return_counts=True)[1]
    
    return plot, p_clusters, cluster_counts

# %%
cluster_and_plot(3, data, pca_1, pca_2)
# Out:
# (<matplotlib.collections.PathCollection at 0x1a1fcd25f8>,
#  array([1, 2, 1, ..., 0, 0, 0], dtype=int32),
#  array([647, 311, 360]))

# %%
cluster_and_plot(4, data, pca_1, pca_2)
# Out:
# (<matplotlib.collections.PathCollection at 0x1a1fd20da0>,
#  array([2, 1, 2, ..., 0, 3, 0], dtype=int32),
#  array([314, 309, 296, 399]))

# %%
cluster_and_plot(5, data, pca_1, pca_2)
# Out:
# (<matplotlib.collections.PathCollection at 0x1a1fe01748>,
#  array([4, 3, 4, ..., 2, 1, 0], dtype=int32),
#  array([149, 380, 193, 307, 289]))

# %% [markdown]
# Going with k = 4 for now...

# %%
data_out = data

data_out["cluster"] = cluster_and_plot(4, data, pca_1, pca_2)[1]

data_out.to_csv("kmeans_clustered_strategies.csv")
